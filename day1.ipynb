# %%
import numpy as np
image=np.array([
    [0,50,100],
    [150,200,250],
    [255,128,64],
])


print(image)
print('shape',image.shape)
print('data type',image.dtype)
print('minimum',image.min())
print('maximum',image.max())
print('mean',image.mean())
# Out:
# [[  0  50 100]
#  [150 200 250]
#  [255 128  64]]
# shape (3, 3)
# data type int64
# minimum 0
# maximum 255
# mean 133.0

# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.ones((500, 500), dtype=np.uint8) * 255

image[50:450, 50:100] = 0

image[50:150, 100:175] = 0
image[150:250, 175:250] = 0
image[150:250, 250:325] = 0
image[50:150, 325:400] = 0

image[50:450, 400:450] = 0

plt.figure(figsize=(6, 6))
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 5, figsize=(15, 3))

# 1. Rectangle
image = np.zeros((400, 400), dtype=np.uint8)
image[ 0:250, 80:320] = 255
axes[0].imshow(image, cmap="gray")
axes[0].set_title("Rectangle")

# 2. Horizontal line
image = np.zeros((400, 400), dtype=np.uint8)
image[195:205, 50:350] = 255
axes[1].imshow(image, cmap="gray")
axes[1].set_title("Horizontal")

# 3. Vertical line
image = np.zeros((400, 400), dtype=np.uint8)
image[50:350, 195:205] = 255
axes[2].imshow(image, cmap="gray")
axes[2].set_title("Vertical")

# 4. Cross
image = np.zeros((400, 400), dtype=np.uint8)
image[195:205, 50:350] = 255
image[50:350, 195:205] = 255
axes[3].imshow(image, cmap="gray")
axes[3].set_title("Cross")

# 5. Border
image = np.zeros((400, 400), dtype=np.uint8)
image[:10, :] = 255
image[-10:, :] = 255
image[:, :10] = 255
image[:, -10:] = 255
axes[4].imshow(image, cmap="gray")
axes[4].set_title("Border")

# Remove axes
for ax in axes:
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
import numpy as np

# Create image
image = np.array([
    [0, 50, 100],
    [150, 200, 250],
    [255, 128, 64]
])

print("Original image:")
print(image)

print("\nShape:", image.shape)
print("Data type:", image.dtype)
print("Minimum:", image.min())
print("Maximum:", image.max())
print("Mean:", image.mean())

# 1. Access three individual pixels
print("Three pixels:")
print(image[0, 1])
print(image[1, 2])
print(image[2, 0])

# 2. Change the center pixel
image[1, 1] = 255

# 3. Change the first row
image[0, :] = 255

# 4. Change the last column
image[:, 2] = 0

print("\nModified image:")
print(image)

# 5. Print statistics
print("\nAfter modifications:")
print("Minimum:", image.min())
print("Maximum:", image.max())
print("Mean:", image.mean())
# Out:
# Original image:
# [[  0  50 100]
#  [150 200 250]
#  [255 128  64]]
#
# Shape: (3, 3)
# Data type: int64
# Minimum: 0
# Maximum: 255
# Mean: 133.0
# Three pixels:
# 50
# 250
# 255
#
# Modified image:
# [[255 255   0]
#  [150 255   0]
#  [255 128   0]]
#
# After modifications:
# Minimum: 0
# Maximum: 255
# Mean: 144.22222222222223

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open("//192.168.1.10/shear all/Original_lena512.JPG")

image = np.array(img)

print("Shape:", image.shape)
print("Data type:", image.dtype)
print("Minimum:", image.min())
print("Maximum:", image.max())
print("Mean:", image.mean())

plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# Shape: (512, 512)
# Data type: uint8
# Minimum: 10
# Maximum: 255
# Mean: 124.06368255615234

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# 1. Load image and ensure it's in RGB mode
img = Image.open(r"\\192.168.1.10\shear all\lena5.jpg").convert("RGB")
rgb_array = np.array(img)

# 2. Extract individual Red, Green, and Blue channels
R = rgb_array[:, :, 0]  # Red channel intensity (0-255)
G = rgb_array[:, :, 1]  # Green channel intensity (0-255)
B = rgb_array[:, :, 2]  # Blue channel intensity (0-255)

# 3. Display full RGB image alongside individual color channels
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

# Full RGB image
axes[0].imshow(rgb_array)
axes[0].set_title("Full RGB Image")
axes[0].axis("off")

# Red Channel
axes[1].imshow(R, cmap="Reds")
axes[1].set_title("Red Channel (R)")
axes[1].axis("off")

# Green Channel
axes[2].imshow(G, cmap="Greens")
axes[2].set_title("Green Channel (G)")
axes[2].axis("off")

# Blue Channel
axes[3].imshow(B, cmap="Blues")
axes[3].set_title("Blue Channel (B)")
axes[3].axis("off")

plt.tight_layout()
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# 1. Load an image
image_path = r"\\192.168.1.10\shear all\lena5.jpg"
img = Image.open(image_path)
image_array = np.array(img)

# 2. Display the original image
plt.figure(figsize=(5, 5))
if len(image_array.shape) == 2:
  plt.imshow(image_array, cmap="gray")
else:
  plt.imshow(image_array)
plt.title("Original Image")
plt.axis("off")
plt.show()

# 3. Print width and height
height, width = image_array.shape[:2]
print(f"3. Width: {width}")
print(f"   Height: {height}")

# 4. Print number of channels when applicable
if len(image_array.shape) == 3:
  channels = image_array.shape[2]
  print(f"4. Number of Channels: {channels}")
else:
  print("4. Number of Channels: 1 (Grayscale image)")

# 5. Print data type
print(f"5. Data Type: {image_array.dtype}")

# 6. Print minimum and maximum values
print(f"6. Minimum Value: {image_array.min()}")
print(f"   Maximum Value: {image_array.max()}")

# 7. Calculate average pixel value
avg_value = image_array.mean()
print(f"7. Average Pixel Value: {avg_value:.2f}")

# 8. Display the RGB channels separately when the image is RGB
if len(image_array.shape) == 3 and image_array.shape[2] >= 3:
  R = image_array[:, :, 0]
  G = image_array[:, :, 1]
  B = image_array[:, :, 2]

  fig, axes = plt.subplots(1, 3, figsize=(12, 4))

  axes[0].imshow(R, cmap="Reds")
  axes[0].set_title("Red Channel")
  axes[0].axis("off")

  axes[1].imshow(G, cmap="Greens")
  axes[1].set_title("Green Channel")
  axes[1].axis("off")

  axes[2].imshow(B, cmap="Blues")
  axes[2].set_title("Blue Channel")
  axes[2].axis("off")

  plt.tight_layout()
  plt.show()
else:
  print("8. Image is not RGB; individual channel display skipped.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 7
#       3 import numpy as np
#       4
#       5 # 1. Load an image
#       6 image_path = r"\\192.168.1.10\shear all\lena5.jpg"
# ----> 7 img = Image.open(image_path)
#       8 image_array = np.array(img)
#       9
#      10 # 2. Display the original image
#
# File ~\tarek\ovenv\Lib\site-packages\PIL\Image.py:3639, in open(fp, mode, formats)
#    3637 if is_path(fp):
#    3638     filename = os.fspath(fp)
# -> 3639     fp = builtins.open(filename, "rb")
#    3640     exclusive_fp = True
#    3641 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\192.168.1.10\\shear all\\lena5.jpg'

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# ضع المسار الكامل الصحيح للصورة هنا
image_path = r"C:\Users\PC-LAB1\Desktop\lena.jpg"  # مثال على مسار سطح المكتب

img = Image.open(image_path).convert("L")
image_array = np.array(img)

# رسم الهيستوجرام
plt.figure(figsize=(8, 4))
plt.hist(image_array.ravel(), bins=256, range=[0, 256], color="black")
plt.title("Image Histogram")
plt.xlabel("Pixel Intensity (0-255)")
plt.ylabel("Number of Pixels")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# 1. تحميل الصورة بتدرج الرمادي (Grayscale)
image_path = r"C:\Users\PC-LAB1\Desktop\lena.jpg"  # مثال على مسار سطح المكتب
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# (تنبيه: إذا لم توفر الصورة، يمكنك استخدام مصفوفة وهمية للتجربة)
if img is None:
  print("لم يتم العثور على الصورة، جاري إنشاء صورة افتراضية...")
  img = np.random.randint(50, 120, (400, 400), dtype=np.uint8)

# 2. تطبيق Histogram Equalization لتحسين التباين
equalized_img = cv2.equalizeHist(img)

# 3. عرض الصورة الأصلية والمعدلة مع الهيستوجرام الخاص بكل منهما
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# الصورة الأصلية
axes[0, 0].imshow(img, cmap="gray")
axes[0, 0].set_title("Original Image")
axes[0, 0].axis("off")

# هيستوجرام الصورة الأصلية
axes[0, 1].hist(img.ravel(), bins=256, range=[0, 256], color="black")
axes[0, 1].set_title("Original Histogram")
axes[0, 1].set_xlim([0, 256])

# الصورة بعد التعديل (Equalized)
axes[1, 0].imshow(equalized_img, cmap="gray")
axes[1, 0].set_title("Equalized Image (Better Contrast)")
axes[1, 0].axis("off")

# هيستوجرام الصورة المعدلة
axes[1, 1].hist(
    equalized_img.ravel(), bins=256, range=[0, 256], color="black"
)
axes[1, 1].set_title("Equalized Histogram")
axes[1, 1].set_xlim([0, 256])

plt.tight_layout()
plt.show()

# %%
import cv2

image = cv2.imread(r"C:\Users\PC-LAB1\Desktop\lena.jpg")

print("Shape:", image.shape)
print("Data type:", image.dtype)

cv2.imshow("Original Image", image)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

#cv2.imwrite(r"C:\Users\PC-LAB1\Desktop\lenas.jpg", image)
# Resize
small = cv2.resize(image, (400, 300))

# Crop
crop = image[100:400, 150:550]

# Flip
horizontal = cv2.flip(image, 1)
vertical = cv2.flip(image, 0)

cv2.imwrite(r"C:\Users\PC-LAB1\Desktop\resized.jpg", small)
cv2.imwrite(r"C:\Users\PC-LAB1\Desktop\crop.jpg", crop)
cv2.imwrite(r"C:\Users\PC-LAB1\Desktop\horizontal_flip.jpg", horizontal)
cv2.imwrite(r"C:\Users\PC-LAB1\Desktop\vertical_flip.jpg", vertical)
# Out:
# Shape: (510, 1020, 3)
# Data type: uint8
# True
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(r"\\192.168.1.10\shear all\image_with_shapes_2.jpeg")

rgb = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(rgb)
plt.axis("off")
plt.show()

# %%
import cv2

# Get image dimensions
height, width = image.shape[:2]

# Find the center of the image
center = (width // 2, height // 2)

# Create rotation matrix
# center = rotation center
# 45 = rotation angle
# 1.0 = original scale
matrix = cv2.getRotationMatrix2D(center, 45, 4.0)

# Apply rotation
rotated = cv2.warpAffine(
    image,
    matrix,
    (width, height)
)

# Save rotated image
cv2.imwrite(r"C:\Users\PC-LAB1\Desktop\rotated.jpg", rotated)
# Out:
# True
